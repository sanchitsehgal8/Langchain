# %%
from langchain_core.tools import tool

# %%
#step 1 : make a function
#step 2 add type hints 
#docstring helps lm to understand the function better
def multiply(a: int, b: int) -> int:
    """Multiplies two numbers together."""
    return a * b

# %%
#add tool decorator to convert the function into a tool
from langchain_core.tools import tool
# Step 3 - add tool decorator
@tool
def multiply(a: int, b:int) -> int:
    """Multiply two numbers"""
    return a*b

# %%
result = multiply.invoke({"a":3, "b":5})
print(result)
print(multiply.name)
print(multiply.description)
print(multiply.args)
print(multiply.args_schema.model_json_schema())
# Out:
# 15
# multiply
# Multiply two numbers
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}
# {'description': 'Multiply two numbers', 'properties': {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}, 'required': ['a', 'b'], 'title': 'multiply', 'type': 'object'}

# %%
# using structured tool 
from langchain_core.tools import StructuredTool
from pydantic import BaseModel, Field
class MultiplyInput(BaseModel):
    a: int = Field(required=True, description="The first number to add")
    b: int = Field(required=True, description="The second number to add")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 2
#       1 # using structured tool
# ----> 2 from langchain.tools import StructuredTool
#       3 from pydantic import BaseModel, Field
#       4 class MultiplyInput(BaseModel):
#
# ImportError: cannot import name 'StructuredTool' from 'langchain.tools' (/Users/sanchit/Desktop/Projects/Langchain/venv/lib/python3.11/site-packages/langchain/tools/__init__.py)

# %%
def multiply_func(a: int, b: int) -> int:
    return a * b 

multiply_tool = StructuredTool.from_function(
    func=multiply_func,
    name="multiply",
    description="Multiply two numbers",
    args_schema=MultiplyInput
)

# %%
result = multiply_tool.invoke({'a':3, 'b':3})

print(result)
print(multiply_tool.name)
print(multiply_tool.description)
print(multiply_tool.args)
